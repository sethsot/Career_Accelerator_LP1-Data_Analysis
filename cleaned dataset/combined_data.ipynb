# %%
import pandas as pd

# %%
data_19 = pd.read_csv("startup_funding2019(Clean_Data).csv")
data_20 = pd.read_csv("2020_dataset_ver4.csv")
data_21 = pd.read_csv("clean_data2021.csv")

# %%
data_19.head(2)
# Out:
#     Company/Brand  Founded HeadQuarter     Sector  \
# 0  Bombay Shaving     2015   Bangalore  Ecommerce
# 1       Ruangguru     2014      Mumbai     Edtech
#
#                                         What_it_does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
#
#                                 Founders              Investor  Amount($)  \
# 0                     Shantanu Deshpande  Sixth Sense Ventures    6300000
# 1  Adamas Belva Syah Devara, Iman Usman.      General Atlantic  150000000
#
#       Stage
# 0   Unknown
# 1  Series C

# %%
data_20.head(2)
# Out:
#   Company/Brand  Founded HeadQuarter    Sector  \
# 0    Aqgromalin     2019     Chennai  Agritech
# 1      Krayonnz     2019   Bangalore    Edtech
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
#
#                            Founders         Investor  Amount($)          Stage
# 0   Prasanna Manogaran, Bharani C L  Angel investors     200000  Stage_unknown
# 1  Saurabh Dixit, Gurudutt Upadhyay  GSF Accelerator     100000       Pre-seed

# %%
data_21.head(2)
# Out:
#     Company/Brand  Founded HeadQuarter      Sector  \
# 0  Unbox Robotics     2019   Bangalore  AI startup
# 1          upGrad     2015      Mumbai      EdTech
#
#                                         What_it_does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
#
#                                    Investor    Amount($)         Stage
# 0               BEENEXT, Entrepreneur First    1200000.0  Pre-series A
# 1  Unilazer Ventures, IIFL Asset Management  120000000.0       Unknown

# %%
# You can concatenate this with other DataFrames to get one data set for your work

df = pd.concat([data_19, data_20, data_21])
df.to_csv('combined_data.csv')

# %%
df.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving     2015   Bangalore        Ecommerce
# 1       Ruangguru     2014      Mumbai           Edtech
# 2        Eduisfun     2015      Mumbai           Edtech
# 3        HomeLane     2014     Chennai  Interior design
# 4        Nu Genes     2004   Telangana         AgriTech
#
#                                         What_it_does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor    Amount($)  \
# 0                               Sixth Sense Ventures    6300000.0
# 1                                   General Atlantic  150000000.0
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   28000000.0
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   30000000.0
# 4           Innovation in Food and Agriculture (IFA)    6000000.0
#
#            Stage
# 0        Unknown
# 1       Series C
# 2  Fresh funding
# 3       Series D
# 4        Unknown

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2321 entries, 0 to 1179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  2321 non-null   object
#  1   Founded        2321 non-null   int64
#  2   HeadQuarter    2229 non-null   object
#  3   Sector         2321 non-null   object
#  4   What_it_does   2321 non-null   object
#  5   Founders       2321 non-null   object
#  6   Investor       2321 non-null   object
#  7   Amount($)      2321 non-null   float64
#  8   Stage          2321 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 181.3+ KB
